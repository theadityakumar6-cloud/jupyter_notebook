# %%
n= input("enter a string: ")

n = n.replace(" ", " ").lower()

if n == n[::-1]:
    print("it is a palindrome.")
else:
    print("not a palindrome.")
# Out:
# enter a string:  level
# it is a palindrome.

# %%
num = int(input("enter a number: "))

fact = 1
for i in range(1,num +1):
    fact*= i

    print("factorial =",fact)
# Out:
# enter a number:  5
# factorial = 1
# factorial = 2
# factorial = 6
# factorial = 24
# factorial = 120

# %%
n = int(input("enter how many fibonacci numbers:"))
num1 = 0
num2 = 1
print(num1, end = " ")
print(num2, end = " ")
s = 0
for i in range(3, n+1):
    s = num1+ num2
    print(s, end=" ")
    num1 = num2
    num2 = s
# Out:
# enter how many fibonacci numbers: 7
# 0 1 1 2 3 5 8

# %%
s = input()
d = {}
for char in s:
    if char in d:
        d[char] += 1
    else:
        d[char] = 1

        print("character occurrence:")
        print(d)
# Out:
#  aditya
# character occurrence:
# {'a': 1}
# character occurrence:
# {'a': 1, 'd': 1}
# character occurrence:
# {'a': 1, 'd': 1, 'i': 1}
# character occurrence:
# {'a': 1, 'd': 1, 'i': 1, 't': 1}
# character occurrence:
# {'a': 1, 'd': 1, 'i': 1, 't': 1, 'y': 1}
