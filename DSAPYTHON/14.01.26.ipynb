# %%
a = float(input("Enter the side of the cube: "))

surface_area = 6 * a * a
volume = a * a * a

print("Surface Area of the cube =", surface_area)
print("Volume of the cube =", volume)
# Out:
# Enter the side of the cube:  656
# Surface Area of the cube = 2582016.0
# Volume of the cube = 282300416.0
