# %%
# Program to explore basic datatypes in Python

a = 10
b = 5.6
c = "Python Programming"
d = True

print("Value of a:", a, "Type:", type(a))
print("Value of b:", b, "Type:", type(b))
print("Value of c:", c, "Type:", type(c))
print("Value of d:", d, "Type:", type(d))
# Out:
# Value of a: 10 Type: <class 'int'>
# Value of b: 5.6 Type: <class 'float'>
# Value of c: Python Programming Type: <class 'str'>
# Value of d: True Type: <class 'bool'>

# %%
# Program to find sum of two numbers

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

sum = num1 + num2
print("Sum of two numbers =", sum)
# Out:
# Enter first number:  5
# Enter second number:  5
# Sum of two numbers = 10

# %%
# Program to calculate area and perimeter of a rectangle

length = float(input("Enter length: "))
breadth = float(input("Enter breadth: "))

area = length * breadth
perimeter = 2 * (length + breadth)

print("Area of rectangle =", area)
print("Perimeter of rectangle =", perimeter)
# Out:
# Enter length:  6
# Enter breadth:  4
# Area of rectangle = 24.0
# Perimeter of rectangle = 20.0
